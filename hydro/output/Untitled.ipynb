# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib import rc
import numpy as np

# %%
data = np.loadtxt('out000001.dat')
print(data.shape)
# Out:
# (256, 9)

# %%
time = data[:,0]
time = time[0]

x = data[:,1]
rho = data[:,2]
vx = data[:,3]
P = data[:,6]

# %%
plt.figure(figsize=(9,9))
plt.plot(x,rho)
plt.title(r"$\rho$ at " + r"$t=$ " + str(time))
plt.xlabel('x')
plt.show()

# %%
plt.figure(figsize=(9,9))
plt.plot(x,P)
plt.title(r"Pressure at " + r"$t=$ " + str(time))
plt.xlabel('x')
plt.show()
